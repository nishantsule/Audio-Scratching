# %%
# Import relevant packages

import AudioS as asc
from bokeh.io import output_notebook
import IPython.display as ipd
output_notebook()
# Out:
# /Users/nishantsule/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
scr = asc.AudioS()
scr.plot_signal(scr.original_sound)
# Out:
# ----------------------
# Enter the audio filename you want to read including the extension:  sample2.wav
# ----------------------
#   <div class="bk-root" id="736cca30-c1ca-46d0-aec8-6933db6ad6a3" data-root-id="1003"></div>

# %%
ipd.Audio(scr.original_signal, rate=scr.framerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
scr.scratch_audiofile(scr.original_sound)
# Out:
# ----------------------
# Do you want to manually enter scratching parameters (y/n):  y
# ----------------------
# Enter the max speed-up in a scratch (number between 1 and 10):  5
# Enter the duration of a scratch in milisecs (> 200 ms):  5000
# Enter the number of scratches (number between 1 and 2):  2
# ----------------------
#   <div class="bk-root" id="d459bbf6-e9fc-4c7f-b0e4-c3c9362564c7" data-root-id="1598"></div>

# %%
ipd.Audio(scr.scratched_signal, rate=scr.framerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
