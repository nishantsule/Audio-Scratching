# %%
# Import relevant packages

import AudioS as asc
from bokeh.io import output_notebook
import IPython.display as ipd
output_notebook()
# Out:
# /Users/nishantsule/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
sceff = asc.AudioS()
ipd.Audio(sceff.signal, rate=sceff.framerate)
# Out:
# ----------------------
# Enter the audio filename you want to read including the extension:  Sample.wav
# ----------------------
#   <div class="bk-root" id="38ca0780-53ae-4927-bd4a-24c81500048f" data-root-id="1003"></div>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fmultiplier = 4.5
sceff.change_playrate(fmultiplier)
ipd.Audio(sceff.signal, rate=sceff.framerate)
# Out:
#   <div class="bk-root" id="caccb236-a419-4c88-9c78-398b02705202" data-root-id="1114"></div>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
