# %%
# Import relevant packages

import AudioS as asc
from bokeh.io import output_notebook
import IPython.display as ipd
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
scr = asc.AudioS()
scr.plot_signal(scr.original_sound)
# Out:
# ----------------------

# %%
ipd.Audio(scr.original_signal, rate=scr.framerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
scr.scratch_audiofile(scr.original_sound)
# Out:
# ----------------------
# Do you want to manually enter scratching parameters (y/n):  y
# ----------------------
# Enter the max speed-up in a scratch (number between 1 and 10):  2.5
# Enter the number of scratches (number between 1 and 2):  2
# ----------------------
#   <div class="bk-root" id="9a1b3219-084e-40c4-9221-9bf7829b7a9a" data-root-id="1102"></div>

# %%
ipd.Audio(scr.scratched_signal, rate=scr.framerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
scr.calc_fft(scr.original_signal)
# Out:
#   <div class="bk-root" id="7fafa4e2-55bc-44e8-a3ee-54fd8be9492d" data-root-id="1211"></div>

# %%
scr.calc_fft(scr.scratched_signal)
# Out:
#   <div class="bk-root" id="07ee6c26-6271-42aa-9614-faeabb9ebcef" data-root-id="1330"></div>
